# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import os
from matplotlib import rc
import matplotlib as mpl
from matplotlib.ticker import MaxNLocator
from matplotlib import ticker

mpl.rcParams.update(mpl.rcParamsDefault)

rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
mpl.rcParams['savefig.dpi'] = 1200
mpl.rcParams['text.usetex'] = True  # not really needed

# %%
# title = r'$\mathrm{Synthetic~(2~obervations)}$'
d2 = [2000, 4000, 6000, 8000, 10000]

runtime_2 = [0.14792784, 0.14793181, 0.14856744, 0.14810046, 0.14806501]
runtime_6 = [0.36847107, 0.37732681, 0.38019697, 0.38454358, 0.39118004]
runtime_10 = [0.96765137, 1.01960345, 1.03805669, 1.04714719, 1.06127810]
runtime_std = [0.00783107, 0.00995871, 0.02235781, 0.39976870, 0.0052526]

f, ax = plt.subplots(figsize=(10,7))

plt.plot(d2, runtime_10, lw=5, color='royalblue', ls="dashdot")
plt.scatter(d2, runtime_10, s=200, color='royalblue', label=r"$p=\frac{10}{d}$")

plt.plot(d2, runtime_6, lw=5, color='gold', ls="dotted")
plt.scatter(d2, runtime_6, s=200, color='gold', label=r"$p=\frac{6}{d}$")

plt.plot(d2, runtime_2, lw=5, color='red', ls="dashed")
plt.scatter(d2, runtime_2, s=200, color='red', label=r"$p=\frac{2}{d}$")


ax.legend(fontsize=32, loc='upper right', bbox_to_anchor=(0.4, 0.75))


plt.xlabel(r"$d$", fontsize=40)
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
ax.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
ax.xaxis.get_offset_text().set_fontsize(40)

xticks = d2
plt.xticks(xticks, fontsize=40)
plt.yticks([0.1, 0.4, 0.7, 1, 1.3], fontsize=40)
plt.ylabel(r"$\mathrm{\#~Seconds}$", fontsize=40)


plt.grid(lw=0.5, ls=":")
plt.tight_layout()
plot_name = f"runtime_syn.pdf"
plt.savefig(plot_name, bbox_inches='tight', format="pdf", dpi=1200)

plt.show()
plt.close()

# %%
# title = r'$\mathrm{Synthetic~(2~obervations)}$'
m = [6e6, 1e8, 3e8, 1.3e9, 1.7e9]

runtime_8 = [2, 24, 48, 110, 150]
runtime_5 = [1, 14.3, 37, 77.3, 109]
runtime_2 = [0.7, 3.8, 12, 21, 32]

f, ax = plt.subplots(figsize=(10,7))

plt.plot(m, runtime_8, lw=5, color='royalblue', ls="dashdot")
plt.scatter(m, runtime_8, s=200, color='royalblue', label=r"$p=0.8$")

plt.plot(m, runtime_5, lw=5, color='gold', ls="dotted")
plt.scatter(m, runtime_5, s=200, color='gold', label=r"$p=0.5$")

plt.plot(m, runtime_2, lw=5, color='red', ls="dashed")
plt.scatter(m, runtime_2, s=200, color='red', label=r"$p=0.2$")

ax.legend(fontsize=32, loc='upper right', bbox_to_anchor=(0.40, 1.00))

plt.xlabel(r"$|\Omega|$", fontsize=40)
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
ax.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
ax.xaxis.get_offset_text().set_fontsize(40)

xticks = m
#plt.xticks([0, 3e8, 1.3e9, 1.7e9], [r'$\mathrm{0}$', r'$\mathrm{0.3}$', r'$\mathrm{1.3}$', r'$\mathrm{1.7}$'], fontsize=40)
plt.xticks([1e8, 5e8, 9e8, 1.3e9, 1.7e9], fontsize=40)
plt.yticks([0, 40, 80, 120, 160], fontsize=40)
#plt.ylim(-0.2, 180)
plt.ylabel(r"$\mathrm{\#~Seconds}$", fontsize=40)



plt.grid(lw=0.5, ls=":")
plt.tight_layout()
plot_name = f"runtime_real.pdf"
plt.savefig(plot_name, bbox_inches='tight', format="pdf", dpi=1200)

plt.show()
plt.close()
