# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import os
from matplotlib import rc
import matplotlib as mpl
from matplotlib.ticker import MaxNLocator
from matplotlib.ticker import ScalarFormatter

# %%
mpl.rcParams.update(mpl.rcParamsDefault)

rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
mpl.rcParams['savefig.dpi'] = 1200
mpl.rcParams['text.usetex'] = True  # not really needed

# %%
# title = r'$\mathrm{Synthetic~(2~obervations)}$'
noise_ratio = [0, 10, 25, 50]

n5000 = [0.0036787, 0.0238743, 0.0607536, 0.1191733]
n5000_std = [0.0000522, 0.0004836, 0.0003901, 0.0011649]

n10000 = [0.0028513, 0.0072910, 0.0192514, 0.0399614,]
n10000_std = [0.0000317, 0.0000501, 0.0001279, 0.0002577]

n20000 = [0.0024157, 0.0030933, 0.0058805, 0.0123903]
n20000_std = [0.0000165, 0.0000291, 0.0000370, 0.0000245]

coeffs = np.polyfit(noise_ratio, n5000, 1)
slope, intercept = coeffs
print(f"slope for n5000: {slope}")
print(f"dis: {intercept}")

coeffs = np.polyfit(noise_ratio, n10000, 1)
slope, intercept = coeffs
print(f"slope for n10000: {slope}")
print(f"dis: {intercept}")
coeffs = np.polyfit(noise_ratio, n20000, 1)
slope, intercept = coeffs
print(f"slope for n20000: {slope}")
print(f"dis: {intercept}")

f, ax = plt.subplots(figsize=(8,7))

#enhance = ob2_rmse_mean / rmse_mean
#enhance = rmse_mean / ob2_rmse_mean
#print(enhance.mean())
#print(ob2_err_mean)
#print(err_mean)

plt.plot(noise_ratio, n5000, lw=3, color='royalblue',ls="dashdot" )
plt.plot(noise_ratio, n10000, lw=3, color='gold', ls="dotted")
plt.plot(noise_ratio, n20000, lw=3, color='red', ls="dashed")

plt.scatter(noise_ratio, n5000, s=100, color='royalblue', label=r"$n=5d$", marker="X")
plt.scatter(noise_ratio, n10000, s=100, color='gold', label=r"$n=10d$")
plt.scatter(noise_ratio, n20000, s=100, color='red', label=r"$n=20d$", marker="D")

plt.errorbar(noise_ratio, n5000, yerr=n5000_std,color='royalblue', fmt='X', capsize=10)
plt.errorbar(noise_ratio, n10000, yerr=n10000_std,color='gold', capsize=10)
plt.errorbar(noise_ratio, n20000, yerr=n20000_std,color='red', fmt='D', capsize=10)

#plt.legend(fontsize=26, loc='center left',bbox_to_anchor=(1, 0.5), ncol=1)
plt.legend(fontsize=36, loc='upper right')

plt.xlabel(r"$\sigma$", fontsize=36)
plt.ylabel(r"$\mathrm{Estimation~Error}$", fontsize=36)


xticks = [0, 10, 25, 50]
plt.xticks(xticks, fontsize=36)
#plt.ticklabel_format(style='sci', scilimits=(0,0), axis='x')
plt.yticks([0, 0.05, 0.1], fontsize=36)
#ax.xaxis.get_offset_text().set_fontsize(26)
plt.gca().invert_xaxis()

plt.grid(lw=0.5, ls=":")
plt.tight_layout()
plot_name = f"privacy_n.pdf"
plt.savefig(plot_name, bbox_inches='tight', format="pdf", dpi=1200)

plt.show()
plt.close()
# Out:
# slope for n5000: 0.0023311366519823784
# dis: 0.002333321145374455
# slope for n10000: 0.000760154449339207
# dis: 0.001185492951541852
# slope for n20000: 0.0002059134801762114
# dis: 0.001569288546255506

# %%
noise_ratio = [0, 10, 25, 50]

r5 = [0.0025909, 0.0056750, 0.0139356, 0.0287550]
r5_std = [0.0000273, 0.0000452, 0.0000588, 0.0004849]

r10 = [0.0028513, 0.0072910, 0.0192514, 0.0399614,]
r10_std = [0.0000317, 0.0000501, 0.0001279, 0.0002577]

r20 = [0.0031365, 0.0100143, 0.0277619, 0.0576536]
r20_std = [0.0000187, 0.0000253, 0.0001629, 0.0003042]

coeffs = np.polyfit(noise_ratio, r5, 1)
slope, intercept = coeffs
print(f"slope for r5: {slope}")
print(f"dis: {intercept}")
coeffs = np.polyfit(noise_ratio, r10, 1)
slope, intercept = coeffs
print(f"slope for r10: {slope}")
print(f"dis: {intercept}")
coeffs = np.polyfit(noise_ratio, r20, 1)
slope, intercept = coeffs
print(f"slope for r20: {slope}")
print(f"dis: {intercept}")

f, ax = plt.subplots(figsize=(8,7))

#enhance = ob2_rmse_mean / rmse_mean
#enhance = rmse_mean / ob2_rmse_mean
#print(enhance.mean())
#print(ob2_err_mean)
#print(err_mean)

plt.plot(noise_ratio, r20, lw=3, color='royalblue',ls="dashdot" )
plt.plot(noise_ratio, r10, lw=3, color='gold', ls="dotted")
plt.plot(noise_ratio, r5, lw=3, color='red', ls="dashed")

plt.scatter(noise_ratio, r20, s=100, color='royalblue', label=r"$r=5$", marker="X")
plt.scatter(noise_ratio, r10, s=100, color='gold', label=r"$r=10$")
plt.scatter(noise_ratio, r5, s=100, color='red', label=r"$r=20$", marker="D")

plt.errorbar(noise_ratio, r20, yerr=r20_std,color='royalblue', fmt='X', capsize=10)
plt.errorbar(noise_ratio, r10, yerr=r10_std,color='gold', capsize=10)
plt.errorbar(noise_ratio, r5, yerr=r5_std,color='red', fmt='D', capsize=10)

plt.legend(fontsize=36, loc='upper right')

plt.xlabel(r"$\sigma$", fontsize=36)
plt.ylabel(r"$\mathrm{Estimation~Error}$", fontsize=36)


xticks = [0, 10, 25, 50]
plt.xticks(xticks, fontsize=36)
#plt.ticklabel_format(style='sci', scilimits=(0,0), axis='x')
plt.yticks([0, 0.05, 0.1], fontsize=36)
#ax.xaxis.get_offset_text().set_fontsize(26)
plt.gca().invert_xaxis()

plt.grid(lw=0.5, ls=":")
plt.tight_layout()
plot_name = f"privacy_r.pdf"
plt.savefig(plot_name, bbox_inches='tight', format="pdf", dpi=1200)

plt.show()
plt.close()
# Out:
# slope for r5: 0.000535728193832599
# dis: 0.0013549008810572697
# slope for r10: 0.000760154449339207
# dis: 0.001185492951541852
# slope for r20: 0.001115303348017621
# dis: 0.0009413788546255523
