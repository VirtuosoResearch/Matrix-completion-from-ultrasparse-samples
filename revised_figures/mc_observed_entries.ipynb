# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import os
from matplotlib import rc
import matplotlib as mpl
from matplotlib.ticker import MaxNLocator

# %%
mpl.rcParams.update(mpl.rcParamsDefault)

rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
mpl.rcParams['savefig.dpi'] = 1200
mpl.rcParams['text.usetex'] = True  # not really needed

# %%
observed_entries_file = '../results/results_data/observed_entries_2_syn_10000_1000_r10_p1e-02.pt'
privacy_tradeoff_file = '../results/results_data/privacy_tradeoff_syn_10000_1000_r10_p1e-02.pt'
users_file = '../results/results_data/users_syn_1000_1000_r10_p1e-02.pt'
mc_file = '../results/results_data/mcmtm_observed_entries_2_syn_10000_1000_r10_p1e-02.pt'

results = torch.load(observed_entries_file)
mc_results = torch.load(mc_file)
privacy_tradeoff_results = torch.load(privacy_tradeoff_file)
users_results = torch.load(users_file)

# %%
# observed entries
X = results['p_list']
print(X)

original_err_mean = results['original_err_mean']
original_err_std = results['original_err_std']
T_prob_err_mean = results['T_prob_err_mean']
T_prob_err_std = results['T_prob_err_std']
T_freq_err_mean = results['T_freq_err_mean']
T_freq_err_std = results['T_freq_err_std']
T_freq_rmse_mean = results['T_freq_rmse_mean']
T_freq_rmse_std = results['T_freq_rmse_std']
SVD_T_err_mean = results['SVD_T_err_mean']
SVD_T_err_std = results['SVD_T_err_std']
#SVD_T_rmse_mean = results['SVD_T_rmse_mean']
#SVD_T_rmse_std = results['SVD_T_rmse_std']
X_original_err_mean = results['X_original_err_mean']
X_original_err_std = results['X_original_err_std']
ob2_err_mean = results['ob2_err_mean']
ob2_rmse_mean = results['ob2_rmse_mean']
print(ob2_err_mean)
mc_err_mean = mc_results['err_mean']
mc_rmse_mean = mc_results['rmse_mean']
oracle_err_mean = mc_results['oracle_err_mean']
oracle_rmse_mean = mc_results['oracle_rmse_mean']
err_mean = results['err_mean']
err_std = results['err_std']
rmse_mean = results['rmse_mean']
rmse_std = results['rmse_std'] 
print(err_mean)
f, ax = plt.subplots(figsize=(8,7))
enhance = ob2_err_mean / err_mean
#enhance = err_mean / ob2_err_mean
print(enhance.mean())

plt.plot(X, mc_err_mean, color='violet',lw=6,ls="dotted")
plt.scatter(X, mc_err_mean, s=400, color='violet', label=r"$\mathrm{Alternating~GD}$", marker="P")
plt.plot(X, ob2_err_mean, lw=6, color='forestgreen', ls="dashed")
plt.scatter(X, ob2_err_mean, s=400, color='forestgreen', label=r"$\mathrm{Nuclear~norm~reg.}$")

plt.plot(X, err_mean, color='tomato',lw=6)
plt.scatter(X, err_mean, s=400, color='tomato', label=r"$\mathrm{Ours}$", marker="D")

plt.legend(fontsize=25, loc='upper right', bbox_to_anchor=(0.85, 0.5))

plt.xlabel(r"$p$", fontsize=40)
plt.ylabel(r"$\mathrm{Estimation~Error}$", fontsize=40)

plt.xticks(fontsize=40)
plt.ticklabel_format(style='sci', scilimits=(0,0), axis='x')
ax.xaxis.get_offset_text().set_fontsize(28)
plt.yticks(fontsize=40)
plt.gca().xaxis.set_major_locator(MaxNLocator(5))
plt.gca().yaxis.set_major_locator(MaxNLocator(4))

plt.grid(lw=0.5, ls=":")
plt.tight_layout()
plot_name = f"uniform_sampling_err.pdf"
plt.savefig(plot_name, bbox_inches='tight', format="pdf", dpi=1200)

plt.show()
plt.close()
# Out:
# [0.002, 0.004, 0.006, 0.008, 0.01]
# [0.97990388 0.886962   0.7385847  0.57709748 0.41344517]
# [0.60084677 0.08729414 0.08208123 0.08975881 0.09644385]
# 6.301205272255567

# %%
# observed entries
title = r'$\mathrm{Synthetic~(10^4~rows)}$'
X = results['p_list']
print(X)
original_err_mean = results['original_err_mean']
original_err_std = results['original_err_std']
T_prob_err_mean = results['T_prob_err_mean']
T_prob_err_std = results['T_prob_err_std']
T_freq_err_mean = results['T_freq_err_mean']
T_freq_err_std = results['T_freq_err_std']
T_freq_rmse_mean = results['T_freq_rmse_mean']
T_freq_rmse_std = results['T_freq_rmse_std']
#SVD_T_err_mean = results['SVD_T_err_mean']
#SVD_T_err_std = results['SVD_T_err_std']
#SVD_T_rmse_mean = results['SVD_T_rmse_mean']
#SVD_T_rmse_std = results['SVD_T_rmse_std']
X_original_err_mean = results['X_original_err_mean']
X_original_err_std = results['X_original_err_std']
ob2_err_mean = results['ob2_err_mean']
ob2_rmse_mean = results['ob2_rmse_mean']
oracle_err_mean = mc_results['oracle_err_mean']
oracle_rmse_mean = mc_results['oracle_rmse_mean']
err_mean = results['err_mean']
err_std = results['err_std']
rmse_mean = results['rmse_mean']
rmse_std = results['rmse_std'] 
print(ob2_rmse_mean)
print(rmse_mean)
f, ax = plt.subplots(figsize=(8,7))
#T_freq_rmse_mean[0] += 0.01
#T_freq_rmse_mean[1] += 0.01
#T_freq_rmse_mean[2] += 0.011
#T_freq_rmse_mean[3] += 0.012
#T_freq_rmse_mean[4] += 0.011
#enhance = ob2_rmse_mean / rmse_mean
#enhance = rmse_mean / ob2_rmse_mean
#print(enhance.mean())

plt.plot(X, mc_rmse_mean, color='violet',lw=6,ls="dotted")
plt.scatter(X, mc_rmse_mean, s=400, color='violet', label=r"$\mathrm{Alternating~GD}$", marker="P")
plt.plot(X, ob2_rmse_mean, lw=6, color='forestgreen', ls="dashed")
plt.scatter(X, ob2_rmse_mean, s=400, color='forestgreen', label=r"$\mathrm{Nuclear~norm~reg.}$")

plt.plot(X, rmse_mean, color='tomato',lw=6)
plt.scatter(X, rmse_mean, s=400, color='tomato', label=r"$\mathrm{Ours}$", marker="D")

plt.legend(fontsize=30, loc='upper right')
# plt.title(title, fontsize=40)

plt.xlabel(r"$p$", fontsize=40)
plt.ylabel(r"$\mathrm{RMSE}$", fontsize=40)

plt.xticks(fontsize=40)
plt.xticks(fontsize=40)
plt.ticklabel_format(style='sci', scilimits=(0,0), axis='x')
ax.xaxis.get_offset_text().set_fontsize(28)
plt.yticks(np.arange(0.2, 0.61, 0.2),fontsize=40)
plt.gca().xaxis.set_major_locator(MaxNLocator(5))
plt.gca().yaxis.set_major_locator(MaxNLocator(4))
#plt.yscale("log", base=10)
#plt.ylim(,1.1)

plt.grid(lw=0.5, ls=":")
#acc_str = f"best train acc: {np.array(train_acc).max():.4f}\nvalid acc: {val_acc[-1]:.4f}\nbest valid acc: {np.array(val_acc).max():.4f}\ngrokking gap: {val_converge-train_converge}"
# plt.annotate(acc_str, xy=(0.2, 0.5), xycoords='axes fraction', fontsize=12, color='purple', ha='center')
# add the annotation text to the overleaf file
plt.tight_layout()
plot_name = f"./plots/mc_observed_entries_10k_rmse.pdf"
plt.savefig(plot_name, bbox_inches='tight', format="pdf", dpi=1200)

plt.show()
plt.close()
# Out:
# [0.002, 0.004, 0.006, 0.008, 0.01]
# []
# [0.34917486 0.13020502 0.12693682 0.12549561 0.12548091]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 41
#      39 plt.plot(X, mc_rmse_mean, color='violet',lw=6,ls="dotted")
#      40 plt.scatter(X, mc_rmse_mean, s=400, color='violet', label=r"$\mathrm{Alternating~GD}$", marker="P")
# ---> 41 plt.plot(X, ob2_rmse_mean, lw=6, color='forestgreen', ls="dashed")
#      42 plt.scatter(X, ob2_rmse_mean, s=400, color='forestgreen', label=r"$\mathrm{Nuclear~norm~reg.}$")
#      44 plt.plot(X, rmse_mean, color='tomato',lw=6)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py:3575, in plot(scalex, scaley, data, *args, **kwargs)
#    3567 @_copy_docstring_and_deprecators(Axes.plot)
#    3568 def plot(
#    3569     *args: float | ArrayLike | str,
#    (...)
#    3573     **kwargs,
#    3574 ) -> list[Line2D]:
# -> 3575     return gca().plot(
#    3576         *args,
#    3577         scalex=scalex,
#    3578         scaley=scaley,
#    3579         **({"data": data} if data is not None else {}),
#    3580         **kwargs,
#    3581     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1478 """
#    1479 Plot y versus x as lines and/or markers.
#    1480
#    (...)
#    1718 (``'green'``) or hex strings (``'#008000'``).
#    1719 """
#    1720 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722 for line in lines:
#    1723     self.add_line(line)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py:499, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     496     axes.yaxis.update_units(y)
#     498 if x.shape[0] != y.shape[0]:
# --> 499     raise ValueError(f"x and y must have same first dimension, but "
#     500                      f"have shapes {x.shape} and {y.shape}")
#     501 if x.ndim > 2 or y.ndim > 2:
#     502     raise ValueError(f"x and y can be no greater than 2D, but have "
#     503                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (5,) and (0,)

# %%
print(original_err_mean[-1])
print(T_prob_err_mean[-1])
print(T_freq_err_mean[-1])
print(ob2_err_mean[-1])
print(err_mean[-1])
# Out:
# 0.9998999238014221
# 32.21894073486328
# 0.6480268239974976
# 0.41384756565093994
# 0.09631749242544174

# %%
ob2_rmse_mean
# Out:
# array([], dtype=float64)
