# %%
import numpy as np
import random as random
from data import *

# %%
d1 = 10
d2 = 10
r = 3
m = d1 * r

# %%
# generate data
M = get_random_matrix(d1, d2, r)
observed_M = get_random_samples(M, m)

# %%
observed_M
# Out:
# 25

# %%
M[0, 0]
# Out:
# -0.25496909029711823

# %%
vals
# Out:
# {(5, 5): -0.06963723725328547,
#  (4, 6): 0.6917402792396081,
#  (6, 4): 0.26155686260089706,
#  (8, 2): -0.2182149019549683,
#  (2, 3): 0.6623086012785885,
#  (0, 6): -1.1058675848062707,
#  (2, 0): 1.372072534269695,
#  (0, 8): -0.07455474978736024,
#  (6, 7): 0.2700005014721436,
#  (0, 0): -1.09775884270666,
#  (8, 5): -1.1922449299772242,
#  (1, 1): -0.042288470590023206,
#  (6, 2): 0.24917547754760322,
#  (2, 7): -1.3761583171590326,
#  (3, 7): -0.7755062321147593,
#  (0, 7): 0.6630205297459988,
#  (6, 3): -0.007476456171586946,
#  (0, 4): -0.48555900366845495,
#  (4, 1): -0.34493780861707607,
#  (5, 3): -0.6906606226287834,
#  (7, 6): 0.8241081888022086,
#  (6, 6): 0.09399058956812802,
#  (5, 8): -2.7379322354600344,
#  (3, 6): 1.9463971518371843,
#  (5, 0): -1.9371362460137094,
#  (8, 8): 0.8223553152540616,
#  (7, 3): 0.11955474595285123,
#  (2, 5): 0.013491613593398242}

# %%
x = np.array([])

x

# %%
x
# Out:
# array([], dtype=float64)
