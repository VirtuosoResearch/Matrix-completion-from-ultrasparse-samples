# %%
import numpy as np
import random
from data import get_random_matrix, get_uniformly_random_samples
from gradient_descent import symmetric_noisy_gradient_descent

# %%
# instance parameters
d = 100
r = 5
p = 5 * d * r / (d**2)

# %%
U = get_random_matrix(d, d, r)

A = U @ U.T

values, S = get_uniformly_random_samples(A, p)

# %% [markdown]
# set up noisy gradient descent update

# %%
eta = 0.001
epochs = 500
noise_var = 5.0
reg = 0.0

X = symmetric_noisy_gradient_descent(values, S, d, eta, epochs, noise_var, reg)

dist = np.linalg.norm(X @ X.T - A, 'fro') / np.linalg.norm(A, 'fro')
print(dist)
# Out:
# 0 0.9999923804126095
# 10 0.9996546886239462
# 20 0.9976786682822516
# 30 0.9871684886082971
# 40 0.9323840552131787
# 50 0.763058939848018
# 60 0.5360462236895637
# 70 0.36053514129664194
# 80 0.2549874431371949
# 90 0.19221676547770328
# 100 0.15153454946682388
# 110 0.12167528677944764
# 120 0.09856318196180869
# 130 0.08127863376331865
# 140 0.06847175872629678
# 150 0.05880740845797532
# 160 0.050508514326676496
# 170 0.043786920711708685
# 180 0.039340080199284866
# 190 0.03506552142752832
# 200 0.03222177477061113
# 210 0.030468958769747
# 220 0.02819108828825631
# 230 0.026982734092937898
# 240 0.02553486575759461
# 250 0.024863343276856884
# 260 0.02388523514686694
# 270 0.022976741539352537
# 280 0.02211658663723006
# 290 0.022253476212302604
# 300 0.021955705479616047
# 310 0.022105894876828326
# 320 0.0220033350138017
# 330 0.02177764734406313
# 340 0.02184211287104314
# 350 0.021460247564623308
# 360 0.021494083406694744
# 370 0.021528819386184474
# 380 0.021579100785371973
# 390 0.02121014917226781
# 400 0.021722580931209007
# 410 0.02144280249003283
# 420 0.02153276454957583
# 430 0.02129581800002516
# 440 0.020909325527717758
# 450 0.02109984702783921
# 460 0.020674255975403594
# 470 0.021384808675488733
# 480 0.02132402291965717
# 490 0.021147144053450067
# 0.03833804291455074

# %%
np.linalg.norm(X, 'fro')
# Out:
# 43.16833269248776

# %%
np.linalg.norm(U, 'fro')
# Out:
# 43.13366789774135

# %% [markdown]
# with regularization

# %%
reg = 0.250

X_reg = symmetric_noisy_gradient_descent(values, S, d, eta, epochs, noise_var, reg)

dist = np.linalg.norm(X_reg @ X_reg.T - A, 'fro') / np.linalg.norm(A, 'fro')
print(dist)
# Out:
# 0 0.9999942076518454
# 10 0.9996543489467588
# 20 0.997782300856069
# 30 0.9877869638121213
# 40 0.9371796716140643
# 50 0.776024616959937
# 60 0.5544588963265334
# 70 0.3789570937341556
# 80 0.26839180976482485
# 90 0.20114616935361132
# 100 0.15667698063309782
# 110 0.12434546830469227
# 120 0.10088193506696344
# 130 0.08370385263187739
# 140 0.0697360773549287
# 150 0.059609156176238395
# 160 0.05204524571855797
# 170 0.045853649901432376
# 180 0.040323822986774775
# 190 0.03664082740503753
# 200 0.033766055211651144
# 210 0.03100742933618923
# 220 0.02915568038409173
# 230 0.027894384505499102
# 240 0.026606919085718404
# 250 0.025690980239780087
# 260 0.025324144270673744
# 270 0.025096325695895632
# 280 0.023978421725597495
# 290 0.02312136282052333
# 300 0.02256563592800598
# 310 0.022642969058135308
# 320 0.022371933321439184
# 330 0.022417681407928013
# 340 0.022133545227740258
# 350 0.022096533799285733
# 360 0.021698995671155602
# 370 0.02151478994723959
# 380 0.02137178406024074
# 390 0.021492875452861996
# 400 0.021349204825150913
# 410 0.021553784810179978
# 420 0.021260032465076417
# 430 0.02115106300424179
# 440 0.021331893900410466
# 450 0.020765611668751002
# 460 0.0211660115131806
# 470 0.021030858922732567
# 480 0.021061426741443887
# 490 0.020926041334747767
# 0.03895461918832594

# %%
np.linalg.norm(A, 'fro') / d
# Out:
# 7.789635005052181

# %%
np.linalg.norm(U, 'fro')
# Out:
# 42.96030985326841
