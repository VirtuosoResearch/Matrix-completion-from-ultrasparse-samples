# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import os
from matplotlib import rc
import matplotlib as mpl
from matplotlib.ticker import MaxNLocator

# %%
mpl.rcParams.update(mpl.rcParamsDefault)

rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
mpl.rcParams['savefig.dpi'] = 1200
mpl.rcParams['text.usetex'] = True  # not really needed

# %%
file = '../results/results_data/sample_complexity_syn_1000_1000_r10_p1e-02.pt'

#results = torch.load(observed_entries_file)
#privacy_tradeoff_results = torch.load(privacy_tradeoff_file)
results = torch.load(file)
# observed entries
title = r'$\mathrm{Synthetic}~(d_1 = 10000)$'
#X = np.array([1000, 2000, 6000, 10000, 20000, 50000])
X = results['d2_list']
p_list = results['p_list']

print(X)
print(p_list)

#original_err_mean = results['original_err_mean']
#original_err_std = results['original_err_std']
#T_prob_err_mean = results['T_prob_err_mean']
#T_prob_err_std = results['T_prob_err_std']
T_freq_err_mean = results['T_freq_err_mean'].reshape(len(X), len(p_list)).T
T_freq_err_std = results['T_freq_err_std'].reshape(len(X), len(p_list)).T
#SVD_T_err_mean = results['SVD_T_err_mean']
#SVD_T_err_std = results['SVD_T_err_std']
#X_original_err_mean = results['X_original_err_mean']
#X_original_err_std = results['X_original_err_std']
#ob2_err_mean = results['ob2_err_mean']
#ob2_rmse_mean = results['ob2_rmse_mean']

ob2_err_mean = results['ob2_err_mean'].reshape(len(X), len(p_list)).T
err_mean = results['err_mean'].reshape(len(X), len(p_list)).T
err_std = results['err_std'].reshape(len(X), len(p_list)).T
#rmse_mean = results['rmse_mean']
#rmse_std = results['rmse_std'] 
plt.figure(figsize=(8,7))
#plt.plot(X, original_err_mean, lw=4, label=r"$\tilde{M}^T\tilde{M}$")
#plt.plot(X, T_prob_err_mean, lw=4, label=r"$T_{\text{prob}}$")
#plt.plot(X, T_freq_err_mean[2], lw=4,linestyle='-.', label=r"$T_{\mathrm{freq}},~p=0.01$")
#plt.plot(X, SVD_T_err_mean, lw=4, label=r"$\mathrm{SVD}$")
#plt.plot(X, ob2_err_mean[0], lw=4,linestyle='-.')
#plt.plot(X, ob2_err_mean[1], lw=4,linestyle='-.')
#plt.plot(X, ob2_err_mean[2], lw=4,linestyle='-.')
print(err_mean)
plt.plot(X, err_mean[0], lw=4)
plt.plot(X, err_mean[1], lw=4)
plt.plot(X, err_mean[2], lw=4, color='limegreen')

#plt.scatter(X, ob2_err_mean[0], s=200,linestyle='-.', label=r"$\|\cdot\|_\star~~\mathrm{reg.},~c=0.02d_2$")
#plt.scatter(X, ob2_err_mean[1], s=200,linestyle='-.', label=r"$\|\cdot\|_\star~~\mathrm{reg.},~c=0.05d_2$")
#plt.scatter(X, ob2_err_mean[2], s=200,linestyle='-.', label=r"$\|\cdot\|_\star~~\mathrm{reg.},~c=0.1d_2$")
plt.scatter(X, err_mean[0], s=200, label=r"$\mathrm{Ours},~c=0.02d_2$")
plt.scatter(X, err_mean[1], s=200, label=r"$\mathrm{Ours},~c=0.05d_2$")
plt.scatter(X, err_mean[2], s=200, color='limegreen', label=r"$\mathrm{Ours},~c=0.1d_2$")





#plt.legend(fontsize=20, loc='upper center',bbox_to_anchor=(0.5, 1.4), ncol=2)
#plt.title(title, fontsize=40, y=1.4)
plt.title(title, fontsize=40)
#plt.legend(fontsize=20, loc='center left',bbox_to_anchor=(1, 0.5), ncol=1)
plt.legend(fontsize=25, loc='upper left', ncol=1)

plt.xlabel(r"$\mathrm{Size}~d_2$", fontsize=40)
plt.ylabel(r"$\mathcal{E}$", fontsize=40)

plt.xticks(fontsize=28)
plt.yticks(fontsize=28)
#plt.yscale("log", base=10)
#plt.ylim(0,1)
#plt.ticklabel_format(style='sci', axis='x', scilimits=(4, 4))
#plt.gca().xaxis.get_offset_text().set_fontsize(40)  

plt.gca().xaxis.set_major_locator(MaxNLocator(4))
plt.gca().yaxis.set_major_locator(MaxNLocator(4))
plt.grid(lw=0.5, ls=":")
#acc_str = f"best train acc: {np.array(train_acc).max():.4f}\nvalid acc: {val_acc[-1]:.4f}\nbest valid acc: {np.array(val_acc).max():.4f}\ngrokking gap: {val_converge-train_converge}"
# plt.annotate(acc_str, xy=(0.2, 0.5), xycoords='axes fraction', fontsize=12, color='purple', ha='center')
# add the annotation text to the overleaf file
#plt.tight_layout()
plot_name = f"./plots/sample_complexity_err.pdf"
plt.savefig(plot_name, bbox_inches='tight', format="pdf", dpi=1200)

plt.show()
plt.close()
# Out:
# /var/folders/2_/r_w1bxyd7yj52gcl_l7jdl2r0000gn/T/ipykernel_74049/3840362226.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   results = torch.load(file)
# [1000, 1500, 2000, 2500, 3000]
# [0.01, 0.02, 0.05]
# [[0.1846775  0.1173833  0.09359316 0.082694   0.09392925]
#  [0.14657177 0.11503779 0.08858804 0.10669465 0.09140334]
#  [0.13295281 0.10341221 0.08528449 0.09842052 0.08893885]]

# %%
file = '../results/results_data/r_sample_complexity_syn_10000_1000_r30_p1e-02.pt'

#results = torch.load(observed_entries_file)
#privacy_tradeoff_results = torch.load(privacy_tradeoff_file)
results = torch.load(file)
# observed entries
title = r'$\mathrm{MovieLens}$'
#X = np.array([1000, 2000, 6000, 10000, 20000, 50000])
X = results['d2_list']
r_list = results['r_list']
print(X)
print(r_list)

#original_err_mean = results['original_err_mean']
#original_err_std = results['original_err_std']
#T_prob_err_mean = results['T_prob_err_mean']
#T_prob_err_std = results['T_prob_err_std']
T_freq_err_mean = results['T_freq_err_mean'].reshape(len(X), len(r_list)).T
T_freq_err_std = results['T_freq_err_std'].reshape(len(X), len(r_list)).T
#SVD_T_err_mean = results['SVD_T_err_mean']
#SVD_T_err_std = results['SVD_T_err_std']
#X_original_err_mean = results['X_original_err_mean']
#X_original_err_std = results['X_original_err_std']
#ob2_err_mean = results['ob2_err_mean']
#ob2_rmse_mean = results['ob2_rmse_mean']

ob2_err_mean = results['ob2_err_mean'].reshape(len(X), len(r_list)).T
err_mean = results['err_mean'].reshape(len(X), len(r_list)).T
err_std = results['err_std'].reshape(len(X), len(r_list)).T
#rmse_mean = results['rmse_mean']
#rmse_std = results['rmse_std'] 
plt.figure(figsize=(8,7))
#plt.plot(X, original_err_mean, lw=4, label=r"$\tilde{M}^T\tilde{M}$")
#plt.plot(X, T_prob_err_mean, lw=4, label=r"$T_{\text{prob}}$")
#plt.plot(X, T_freq_err_mean[2], lw=4,linestyle='-.', label=r"$T_{\mathrm{freq}},~p=0.01$")
#plt.plot(X, SVD_T_err_mean, lw=4, label=r"$\mathrm{SVD}$")
#plt.plot(X, ob2_err_mean[0], lw=4,linestyle='-.')
#plt.plot(X, ob2_err_mean[1], lw=4,linestyle='-.')
#plt.plot(X, ob2_err_mean[2], lw=4,linestyle='-.')
plt.plot(X, err_mean[0], lw=4)
plt.plot(X, err_mean[1], lw=4)
plt.plot(X, err_mean[2], lw=4, color='limegreen')
# prd2
#plt.scatter(X, ob2_err_mean[0], s=200,linestyle='-.', label=r"$\|\cdot\|_\star~~\mathrm{reg.},~c=0.25d_2$")
#plt.scatter(X, ob2_err_mean[1], s=200,linestyle='-.', label=r"$\|\cdot\|_\star~~\mathrm{reg.},~c=0.5d_2$")
#plt.scatter(X, ob2_err_mean[2], s=200,linestyle='-.', label=r"$\|\cdot\|_\star~~\mathrm{reg.},~c=0.75d_2$")
plt.scatter(X, err_mean[0], s=200, label=r"$\mathrm{Ours},~c=0.25d_2$")
plt.scatter(X, err_mean[1], s=200, label=r"$\mathrm{Ours},~c=0.5d_2$")
plt.scatter(X, err_mean[2], s=200, color='limegreen', label=r"$\mathrm{Ours},~c=0.75d_2$")





#plt.legend(fontsize=20, loc='upper center',bbox_to_anchor=(0.5, 1.4), ncol=2)
#plt.title(title, fontsize=40, y=1.4)
#plt.title(title, fontsize=40)
#plt.legend(fontsize=20, loc='center left',bbox_to_anchor=(1, 0.5), ncol=1)
plt.legend(fontsize=25, loc='upper left', ncol=1)

plt.xlabel(r"$\mathrm{Size}~d_2$", fontsize=40)
plt.ylabel(r"$\mathcal{E}$", fontsize=40)

plt.xticks(fontsize=28)
plt.yticks(fontsize=28)
#plt.yscale("log", base=10)
#plt.ylim(,1.1)
#plt.ticklabel_format(style='sci', axis='x', scilimits=(4, 4))
#plt.gca().xaxis.get_offset_text().set_fontsize(40)  

plt.gca().xaxis.set_major_locator(MaxNLocator(4))
plt.gca().yaxis.set_major_locator(MaxNLocator(4))
plt.grid(lw=0.5, ls=":")
#acc_str = f"best train acc: {np.array(train_acc).max():.4f}\nvalid acc: {val_acc[-1]:.4f}\nbest valid acc: {np.array(val_acc).max():.4f}\ngrokking gap: {val_converge-train_converge}"
# plt.annotate(acc_str, xy=(0.2, 0.5), xycoords='axes fraction', fontsize=12, color='purple', ha='center')
# add the annotation text to the overleaf file
#plt.tight_layout()
plot_name = f"./plots/r_sample_complexity_err.pdf"
plt.savefig(plot_name, bbox_inches='tight', format="pdf", dpi=1200)

plt.show()
plt.close()
# Out:
# [1000, 1500, 2000, 2500, 3000]
# [5, 10, 15]
# /var/folders/2_/r_w1bxyd7yj52gcl_l7jdl2r0000gn/T/ipykernel_74049/3767279257.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   results = torch.load(file)
